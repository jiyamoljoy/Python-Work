# %%
import pandas as pd
import numpy as np

# %%
dict_line = {'Day':['Tue 09','Wed 10','Thu 11','fri 12','Sat 13','Sun 14','Mon 15','Tue 16','Wed 17','Thu 18'],'Temperature': [33,33,33,31,31,32,33,33,33,33]}

g1_line =pd.DataFrame(dict_line)
g1_line
# Out:
#       Day  Temperature
# 0  Tue 09           33
# 1  Wed 10           33
# 2  Thu 11           33
# 3  fri 12           31
# 4  Sat 13           31
# 5  Sun 14           32
# 6  Mon 15           33
# 7  Tue 16           33
# 8  Wed 17           33
# 9  Thu 18           33

# %%
g1_line.plot('Day','Temperature');
